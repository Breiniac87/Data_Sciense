# %% [markdown]
# <a href="https://colab.research.google.com/github/Breiniac87/Data_Sciense/blob/main/Text_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers sentencepiece

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from transformers import pipeline

# %% [markdown]
# # **Тональность на английком**

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
# для англ текста
results = classifier(
  "I love this place.",
)
results
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998842477798462}]

# %% [markdown]
# # **Тональность текста**

# %%
classifier = pipeline("sentiment-analysis", model="blanchefort/rubert-base-cased-sentiment")
# Out:
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
results = classifier(
  "я люблю этот место."
)
results
# Out:
# [{'label': 'POSITIVE', 'score': 0.9787737727165222}]

# %% [markdown]
# # **Определяем токсичность текста**

# %%
classifier = pipeline("text-classification", model="SkolkovoInstitute/russian_toxicity_classifier")
# Out:
# config.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
results = classifier(
  "мамкин кубер-докер смузихлеб"
)
results
# Out:
# [{'label': 'neutral', 'score': 0.9289957880973816}]

# %% [markdown]
# # **Перевод текста**

# %%
translator = pipeline("translation_ru_to_en", model="Helsinki-NLP/opus-mt-ru-en")
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/307M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/803k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
reults = translator("""
балтийское море  старые европейские улочки и марципан  едем с командой nt праздновать рождество в калининграде  немного полезной информации для вас
 для первоначального исследования города будет достаточно 3 4 дней  наш маршрут составлен таким образом  чтобы объехать всю область и посмотреть
 достопримечательности  добраться до калининграда можно самолетом  идеальный вариант дальше   задержаться на подольше и вернуться туда  где особенно понравилось
   короткий свод  что мы обязательно посетим вместе    кафедральный собор   рыбную деревню   район амалиенау   светлогорск и зеленоградск заедем в спа центр nordic spa
   послушаем органный концерт и погуляем по местным ярмаркам  чтобы зарядиться новогодним настроением  5 8 января    58 500  чтобы узнать подробный маршрут путешествия и что
   включено в стоимость  ставь   в комментариях
 """)
results
# Out:
# [{'translation_text': 'Kaliningrad and the area that to look at the day of the youth guide to en masse you to the atmosphere of the most western corner of Russia to introduce the history of nature to a unique place and man this land we walk to the Kaliningrad to see German architecture to meet the interesting museum and the most tasty cafeteria restaurant and calyningrad bar to study the coast and also to enjoy the view of the Kursh and the Baltic kos, except to visit the east region and to open up to ourselves the architecture of the black and right-wing malyk in the detail that this issue of the trailer history of the region to meet the caliningrad of the German architecture, the beginning of the defensive line of the Kenigsberg fort_denhoff galonic map of the Kaliningrad, the interesting design of the kalinistic and the kalopunoral kosus the Baltic firefighting of the baltisk and the Baltic kos of the right-handed and the railway gernastical point of interest'}]

# %% [markdown]
# # **Генерация текста**

# %%
generator = pipeline('text-generation', model='sberbank-ai/rugpt3large_based_on_gpt2')
# Out:
# config.json:   0%|          | 0.00/622 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.14G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]

# %%
results = generator(
  "Я изучаю датасаенс не потому что я хочу учиться" , max_length=30
)
results
# Out:
# [{'generated_text': 'Я изучаю датасаенс не потому что я хочу учиться, а потому что я хочу знать, что это такое.\n\nЯ не хочу,'}]

# %%
results[0]['generated_text']
# Out:
# 'Я изучаю датасаенс не потому что я хочу учиться, а потому что я хочу знать, что это такое.\n\nЯ не хочу,'

# %% [markdown]
# # **Ответы на вопросы**

# %%
qa_model = pipeline("question-answering", model="AlexKay/xlm-roberta-large-qa-multilingual-finedtuned-ru")
# Out:
# config.json:   0%|          | 0.00/781 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/516 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s
 замедляться в земля восточный пруссия нашабалтика отпуск
         """

# %%
question="какое море в светлогорске?"

# %%
results= qa_model(question=question, context=context)
results
# Out:
# {'score': 0.45610812306404114,
#  'start': 6222,
#  'end': 6238,
#  'answer': ' балтийский море'}

# %% [markdown]
# # **Извлеченеи сущностей**

# %%
classifier1 = pipeline("ner", model="Babelscape/wikineural-multilingual-ner")

# %%
results1 = classifier1("Меня зовут Антон и я живу в Москве")
results1
# Out:
# [{'label': 'NEUTRAL', 'score': 0.47616761922836304}]

# %% [markdown]
# # **суммаризация**

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# %%
ARTICLE = """
Kaliningrad and the area that to look at the day of the youth guide to en masse you to the atmosphere of the most western corner of Russia to introduce the history of nature to a unique place and man this land we walk to the Kaliningrad to see German architecture to meet the interesting museum and the most tasty cafeteria restaurant and calyningrad bar to study the coast and also to enjoy the view of the Kursh and the Baltic kos, except to visit the east region and to open up to ourselves the architecture of the black and right-wing malyk in the detail that this issue of the trailer history of the region to meet the caliningrad of the German architecture, the beginning of the defensive line of the Kenigsberg fort_denhoff galonic map of the Kaliningrad, the interesting design of the kalinistic and the kalopunoral kosus the Baltic firefighting of the baltisk and the Baltic kos of the right-handed and the railway gernastical point of interest
"""

# %%
print(summarizer(ARTICLE, max_length=130, min_length=30, do_sample=False))
# Out:
# [{'summary_text': 'Kaliningrad and the area that to look at the day of the youth guide to en masse you to the atmosphere of the most western corner of Russia. The history of nature to a unique place and man this land.'}]

# %%
ARTICLE = """ МОСКВА, 15 фев — РИА Новости. Послы стран ЕС могли одобрить новый пакет санкций против России еще накануне, но не смогли сделать этого из-за позиции Венгрии, пишет газета Financial Times.
"Венгрия была единственной, кто голосовал против на встрече послов стран ЕС вчера, в противном случае был бы одобрен санкционный пакет, нацеленный против почти 200 физлиц и компаний из России, Китая и других стран", — сообщило издание. Как заявил неназванный чиновник,
Будапешт не согласился из-за китайских компаний. По словам другого чиновника, венгерский посол "попросил немного больше времени для анализа содержания предложений". Как заявили чиновники, обсуждения по вопросу санкций продолжатся, и, вероятно, их также рассмотрят министры стран — членов ЕС на встречах на следующей неделе. Газета Politico отметила, что такая ситуация ставит под сомнение стремление Евросоюза ввести новый пакет санкций против России к 24 февраля. При этом, как ожидают несколько дипломатов, говоривших на условиях анонимности, задержка не должна означать, что символический срок будет пропущен. В январе высокопоставленный европейский источник сообщил, что в настоящее время идет обсуждение 13-го пакета антироссийских санкций. По его словам, новые санкции планируется принять до 24 февраля, такую цель якобы поставил глава дипломатии Евросоюза Жозеп Боррель. Венгрия с начала конфликта на Украине выступает против санкций на российские энергоносители и оказания военной помощи Киеву. В марте 2022 года парламент страны издал указ, запрещающий поставлять в постсоветскую республику оружие с территории страны. Так, Сийярто объяснял, что Будапешт стремится обезопасить Закарпатье, в котором живут этнические венгры, а грузы с вооружениями, переправляемые через его территорию, стали бы законной военной целью.
Руководство страны не раз заявляло, что выступает за скорейшее начало мирных переговоров.
"""

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer

MODEL_NAME = 'basil-77/rut5-base-absum-hh'
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model.eval();

def summarize_text(text, model, tokenizer, num_beams=5):
    # Preprocess the text
    inputs = tokenizer.encode(
        "summarize: " + text,
        return_tensors='pt',
        max_length=1024,
        truncation=True
    )

    # Generate the summary
    summary_ids = model.generate(
        inputs,
        max_length=64,
        num_beams=num_beams,
        # early_stopping=True,
    )

    # Decode and return the summary
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)
# Out:
# config.json:   0%|          | 0.00/872 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/977M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/329 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/828k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# text:  Организация и контроль рабочего процесса Эксплуатация зданий и сооружений Ремонтные работы Техническое обслуживание Энергетика Первичная бухгалтерская документация Работа с электронным документооборотом Договорная работа Оформление ведомости объёмов строительных, электромонтажных работ Работа с технической документацией Техническая эксплуатация Ведение переговоров Противопожарная безопасность Монтаж оборудования Административно-хозяйственная деятельность
# summary:  Заместитель начальника отдела эксплуатации зданий и сооружений

# %%
text = 'калининград и область что посмотреть за день молодежный путеводитель погружать вы в атмосфера самый_западный уголок россия познакомить с история природа уникальный место и человек этот земля мы прогуливаться по калининград увидеть немецкий_архитектура познакомиться с интересный музей и самый вкусный кафе ресторан и бар калининград изучать побережье а также наслаждаться вид куршский и балтийский коса кроме это побывать на восток область и открывать для себя сохраняться архитектура черняховск и правдинск в деталь о что этот выпуск трейлер история регион знакомство с калининград немецкий_архитектура начало_век оборонительный линия кенигсберг форт_денхофф гастрономический карта калининград интересный деталь калининград зеленоградск куршский_коса балтийский серфинг светлогорск балтийск и балтийский коса правдинск и железнодорожный черняховск интересный точка область фильм создавать при сотрудничество с центр молодежный туризм при грантовый поддержка федеральный агентство по дело молодежь команда проект александр_пусько режиссер оператор сценарий монтаж кристина можаев исполнительный продюсер елена филиппов автор идея мария пассер илья казанков александр_пусько оператор дрон арсений заянчковский александр_пусько анимационный дизайн александр буйницкий графический дизайн голос за кадр наталия рыженков калининград калининградскаяобласть янтарный светлогорск зеленоградск балтийск балтйискаякос куршскаякос черняховск серфингнабалтика правдинск_железнодорожный'

summary = summarize_text(text=text,
              model=model,
              tokenizer=tokenizer)
print('text: ', text)
print('summary: ', summary)

#text:  Организация и контроль рабочего процесса Эксплуатация зданий и сооружений Ремонтные работы Техническое обслуживание Энергетика Первичная бухгалтерская документация Работа с электронным документооборотом Договорная работа Оформление ведомости объёмов строительных, электромонтажных работ Работа с технической документацией Техническая эксплуатация Ведение переговоров Противопожарная безопасность Монтаж оборудования Административно-хозяйственная деятельность
#summary:  Руководитель отдела эксплуатации зданий и сооружений
# Out:
# text:  калининград и область что посмотреть за день молодежный путеводитель погружать вы в атмосфера самый_западный уголок россия познакомить с история природа уникальный место и человек этот земля мы прогуливаться по калининград увидеть немецкий_архитектура познакомиться с интересный музей и самый вкусный кафе ресторан и бар калининград изучать побережье а также наслаждаться вид куршский и балтийский коса кроме это побывать на восток область и открывать для себя сохраняться архитектура черняховск и правдинск в деталь о что этот выпуск трейлер история регион знакомство с калининград немецкий_архитектура начало_век оборонительный линия кенигсберг форт_денхофф гастрономический карта калининград интересный деталь калининград зеленоградск куршский_коса балтийский серфинг светлогорск балтийск и балтийский коса правдинск и железнодорожный черняховск интересный точка область фильм создавать при сотрудничество с центр молодежный туризм при грантовый поддержка федеральный агентство по дело мо
# ...
