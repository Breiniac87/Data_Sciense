# %% [markdown]
# <a href="https://colab.research.google.com/github/Breiniac87/Data_Sciense/blob/main/%D0%BB%D0%B5%D0%BC%D0%BC%D0%B0%D1%82%D0%B8%D0%B7%D0%B0%D1%8F%D1%86%D0%B8_%D0%B8_%D1%87%D0%B0%D1%81%D1%82%D0%BE%D1%82%D0%BD%D0%BE%D1%81%D1%82%D1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gensim

# %%
pip install python-Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.0 MB/s eta 0:00:00
# ...

# %%
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gensim
from collections import Counter

# %%
# из библиотеки google.colab импортируем класс files
from google.colab import files

# создаем объект этого класса, применяем метод .upload()
upload = files.upload()
# Out:
#      <input type="file" id="files-e2f4a798-4dba-44df-881f-dfc2ea3a8212" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2f4a798-4dba-44df-881f-dfc2ea3a8212">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel(io.BytesIO(upload['filtered_by_products (1).xlsx']))

# %%
df.head(1)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
#
#                                               report  \
# 0  Очень удобное расположение - на берегу Верхнег...
#
#                                                 text  \
# 0  очень удобное расположение на берегу верхнего ...
#
#                                       lemmatize_text  food_related
# 0  очень удобный расположение на берег верхний оз...             1

# %%
lemated_list = df.lemmatize_text.to_list()
lemated_text = ' '.join(lemated_list)
lemated_list_of_words = lemated_text.split(' ')

# %%
lemated_list_of_words[0]
# Out:
# 'очень'

# %%
lemated_list_of_words
# Out:
# ['очень',
#  'удобный',
#  'расположение',
#  'на',
#  'берег',
#  'верхний',
#  'озеро',
#  'рядом',
#  'с',
#  'отель',
#  'mercury',
#  'в',
#  'который',
#  'остановиться',
#  'пользоваться',
#  'популярность',
#  'поэтому',
#  'столик',
#  'заказать',
#  'заранее',
#  'шикарный',
#  'вид',
#  'из',
#  'панорамный',
#  'окно',
#  '2',
#  'этаж',
#  'на',
#  'озеро',
#  'даже',
#  'в',
#  'дождливый',
#  'погода',
#  'очень',
#  'внимательный',
#  'дружелюбный',
#  'персонал',
#  'готовый',
#  'согреть',
#  'свой',
#  'внимание',
#  'желание',
#  'сделать',
#  'ваш',
#  'пребывание',
#  'в',
#  'ресторан',
#  'запоминаться',
#  'небольшой',
#  'но',
#  'весьма',
#  'представительный',
#  'винный',
#  'карта',
#  'с',
#  'вино',
#  'достойный',
#  'качество',
#  'и',
#  'весьма',
#  'демократичный',
#  'цена',
#  'особенно',
#  'если',
#  'сравнивать',
#  'с',
#  'московский',
#  'зазеркалье',
#  'и',
#  'не',
#  'ставить',
#  'амбициозный',
#  'цель',
#  'купить',
#  'дорогой',
# ...

# %%
len(lemated_list_of_words) # всего слов
# Out:
# 649284

# %%
len(set(lemated_list_of_words)) # всего  уникальныхслов
# Out:
# 20904

# %%
word_dict = Counter(lemated_list_of_words)
word_dict_common = word_dict.most_common()[:20]
word_dict_common[:10]
# Out:
# [('и', 26809),
#  ('в', 17157),
#  ('не', 13198),
#  ('очень', 12237),
#  ('с', 9920),
#  ('на', 9615),
#  ('быть', 7732),
#  ('вкусный', 7549),
#  ('всё', 6686),
#  ('что', 6623)]

# %%
len([ i[0] for i in word_dict_common if i[1] > 5])
# Out:
# 20

# %%
list_uniq_words = list(set(lemated_list_of_words))

# %%
list_uniq_words

# %%
df_uniq_product = pd.read_excel('unique_products.xlsx')

# %%
len(df_uniq_product.unique_products)
# Out:
# 536

# %%
word_counts = {}

# %%
len(set(list_uniq_words))
# Out:
# 20904

# %%
for word in df_uniq_product.unique_products:
  word_counts[word]= lemated_list_of_words.count(word)

# %%
import pandas as pd
df_word_counts =pd.DataFrame(list(word_counts.items()), columns=['word', 'count']).sort_values(by='count', ascending=False)
df_word_counts.to_excel('Частота_вхождения_слов_с_продуктами.xlsx', index=False)

# %%
pd

# %%
word_counts.sort_values()

# %%
word_counts

# %%
flatten_review_list[:10]
# Out:
# ['хотеться',
#  'уехать',
#  'неделя',
#  'зеленоградск',
#  'снять',
#  'домик',
#  'среди',
#  'дерево',
#  'пара',
#  'минута']

# %%
from collections import Counter

words = flatten_review_list
word_dict = Counter(words)
word_dict.most_common()[:10]
# Out:
# [('светлогорск', 2986),
#  ('море', 1933),
#  ('калининград', 1491),
#  ('город', 1000),
#  ('зеленоградск', 959),
#  ('это', 844),
#  ('пляж', 749),
#  ('балтийский', 630),
#  ('день', 628),
#  ('год', 589)]

# %%
for i in range(3, 11):
  words = word_dict.most_common()
  print(i, ':', len([item for item in words if item[1] >= i])) # совсем мало :)
# Out:
# 3 : 5581
# 4 : 4369
# 5 : 3653
# 6 : 3127
# 7 : 2742
# 8 : 2476
# 9 : 2249
# 10 : 2030

# %%
words = word_dict.most_common()
len([item for item in words if item[1] >= 4])
# Out:
# 4369

# %%
filtered_words = [item for item in words if item[1] >= 4]
filtered_words[:50]
# Out:
# [('светлогорск', 2986),
#  ('море', 1933),
#  ('калининград', 1491),
#  ('город', 1000),
#  ('зеленоградск', 959),
#  ('это', 844),
#  ('пляж', 749),
#  ('балтийский', 630),
#  ('день', 628),
#  ('год', 589),
#  ('место', 546),
#  ('область', 518),
#  ('который', 516),
#  ('очень', 508),
#  ('янтарный', 502),
#  ('наш', 487),
#  ('калининградский', 468),
#  ('ребёнок', 408),
#  ('дорога', 385),
#  ('балтика', 372),
#  ('балтийскоемор', 365),
#  ('самый', 357),
#  ('свой', 350),
#  ('янтарь', 338),
#  ('красивый', 335),
#  ('отпуск', 329),
#  ('время', 327),
#  ('музей', 300),
#  ('путешествие', 281),
#  ('один', 278),
#  ('лето', 274),
#  ('хороший', 273),
#  ('такой', 271),
#  ('человек', 262),
#  ('променад', 260),
#  ('россия', 259),
#  ('берег', 252),
#  ('каждый', 250),
#  ('новый', 249),
#  ('сентябрь', 247),
#  ('дом', 245),
#  ('набережная', 240),
#  ('курорт', 237),
#  ('вид', 224),
#  ('куршский', 222),
#  ('балтийск', 217),
#  ('kaliningrad', 216),
#  ('побережье', 216),
# ...

# %%
with open("output15.txt", "w") as file:
    file.write(','.join(flatten_review_list))

# %%
 flatten_review_list
