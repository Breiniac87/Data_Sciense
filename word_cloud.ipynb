# %% [markdown]
# <a href="https://colab.research.google.com/github/Breiniac87/Data_Sciense/blob/main/word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wordcloud

# %%
import numpy as np
from PIL import Image,ImageOps
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
from scipy.ndimage import gaussian_gradient_magnitude

# %%
file=open('sample_data/output15.txt','r')

# %%
text=file.read()

# %%
canvas_width=1920
canvas_height=1080

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.add("это")

# %%
wordcloud = WordCloud(width=canvas_width,height=canvas_height).generate(text)

# %%
wordcloud.to_file('tourism.png')

# %%
plt.imshow(wordcloud, interpolation='bilinear')

# %%
plt.axis('off')
plt.show()
