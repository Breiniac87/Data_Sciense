# %% [markdown]
# <a href="https://colab.research.google.com/github/Breiniac87/Data_Sciense/blob/main/GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# ...

# %%
import os
from openai import OpenAI
import pandas as pd

# %%
# Установка переменной среды
os.environ["OPENAI_API_KEY"] = "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"
# Получение ключа из переменной среды
api_key = os.getenv("OPENAI_API_KEY")
# client = Client(api_key=api_key)  # передаем ключ как именованный аргумент


from openai import OpenAI
client = OpenAI()

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",


  messages=[
    # {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": """
for a, b in df[['word', 'частотность']].values:
  with open('result.txt','a') as file:
    file.write(multiply_word(a, b)) исправь код чтобы каждая запись в файл начиналась с новой строки

    """}
  ]
)
print(completion.choices[0].message.content)
# print(completion.choices[0].message)
# Out:
# for a, b in df[['word', 'частотность']].values:
#     with open('result.txt', 'a') as file:
#         file.write('\n' + multiply_word(a, b))

# %%
a = completion.choices[0].message.content

# %%
a
# Out:
# 'кофе ; Напитки ; 2\nпицца ; Фастфуд ; 5\nпиво ; Напитки ; 2\nсалат ; Закуски ; 1\nмясо ; Основные блюда ; 3\nшашлык ; Основные блюда ; 3\nсуп ; Закуски ; 1\nчай ; Напитки ; 2\nрыба ; Основные блюда ; 3\nбургер ; Фастфуд ; 5\nролл ; Фастфуд ; 5\nкоктейль ; Напитки ; 2\nкурица ; Основные блюда ; 3\nшаверма ; Фастфуд ; 5\nвино ; Напитки ; 2\nговядина ; Основные блюда ; 3\nовощ ; Закуски ; 1\nсыр ; Закуски, Десерт ; 1, 4\nпаста ; Основные блюда ; 3\nхлеб ; Закуски ; 1\nморепродукт ; Основные блюда ; 3\nкартошка ; Закуски ; 1\nстейк ; Основные блюда ; 3\nмороженое ; Десерт ; 4\nкреветка ; Основные блюда ; 3\nборщ ; Основные блюда ; 3\nкруассан ; Закуски ; 1\nгриль ; Основные блюда ; 3\nблин ; Закуски, Десерт ; 1, 4\nпельмень ; Основные блюда ; 3\nлапша ; Основные блюда ; 3'

# %%
.to_excel('result.xlsx')

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",


  messages=[
    # {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": """


На входе есть группы продуктов питания
1) ресторан, все что связано с рыбой, пивом, с национальной кухней, с кухней зарубежных стран
2) бар: молочная продуктция, пивная, винная, кофейная коктейли-бар, гриль-бар
3) кафе: кафе-мороженое, кафе-кондинтерское, кафе-молочная
4) столовая: общественного типа, диетического типа
5) закусочная: общественного типа, специализированного типа (сосисочная, пельменная, блинная, пирожковая, пончиковая, шашлыфчная, чайная, пицерия)


Есть список продуктов:
кофе пицца пиво салат мясо шашлык суп чай рыба бургер ролл коктейль курица шаверма вино говядина овощ сыр паста хлеб морепродукт картошка стейк мороженое креветка борщ круассан гриль блин пельмень лапша
фри баклажан рис плов кальмар торт картофель лимонад хачапури гриб булочка алкоголь котлета тунец вафля масло колбаска капуста пюре чебурек лосось яйцо свинина сырник лагман солянка каша чизкейк ребро утка
хинкали устрица кебаб пирожное морс блинчик драник лук помидор мидия фастфуд омлет лимон сало сосиска пирог филе вишня вареник тартар угорь селёдка печень паштет шоколад какао ягода гамбургер телятина краб
бифштекс чеснок уха медовик оливье гребешок бутерброд груша тост манго спагетти штрудель ризотто макароны клубника сэндвич ростбиф сельдь форель ананас банан хотдог водка малина чипс брускетта мандарин рулет
  апельсин творог колбаса томат карри корица яблоко карамель яичница трюфель оливка шампанское гречка конфета карпаччо жаркое окрошка чипсы йогурт виски кукуруза тортилья пончик клюква кокос кекс барашек чизбургер
  квас желе фрикаделька гуляш голубец пломбир рибай виноград моцарелла щи тарталетка пахлава аперитив кабачок бефстроганов мусс попкорн арбуз маршмеллоу беляш грейпфрут шницель кефир лимончелло лагер винегрет
    милкшейк крендель персик тарт изюм маффин улитка киви рагу вафелька медовуха горошек шпрот рататуй джем сом мартини фондю кисель карбонат масленица дыня гаспаччо манты чахохбили пудинг тапас стурганин


из этого списка каждому слову поставь в соответствие группы, если слову соответствует несколько групп, перечисль их через запятую. Не пропусти ни одного слова из списка!


    """}
  ]
)
print(completion.choices[0].message.content)
# print(completion.choices[0].message)
# Out:
# кофе - бар, кафе
# пицца - закусочная
# пиво - ресторан, бар
# салат - столовая
# мясо - ресторан
# шашлык - закусочная
# суп - столовая
# чай - закусочная, столовая
# рыба - ресторан
# бургер - закусочная
# ролл - ресторан
# коктейль - бар
# курица - столовая
# шаверма - закусочная
# вино - ресторан, бар
# говядина - ресторан
# овощ - столовая
# сыр - закусочная
# паста - ресторан
# хлеб - столовая
# морепродукт - ресторан
# картошка - столовая
# стейк - ресторан
# мороженое - кафе
# креветка - ресторан
# борщ - столовая
# круассан - закусочная
# гриль - бар
# блин - закусочная
# пельмень - закусочная
# лапша - закусочная, ресторан
# фри - закусочная
# баклажан - ресторан
# рис - ресторан
# плов - ресторан
# кальмар - ресторан
# торт - кафе
# картофель - столовая
# лимонад - бар
# хачапури - закусочная
# гриб - ресторан
# булочка - закусочная
# алкоголь - ресторан, бар
# котлета - закусочная, столовая
# тунец - ресторан
# вафля - кафе
# масло - ресторан
# колбаска - закусочная
# ...

# %%
# print(completion.choices[0].message.content)
# Out:
# Группа 1: Напитки
# кофе пиво чай вино лимонад водка квас виски лагер лимончелло медовуха мартини
#
# Группа 2: Блюда из мяса
# мясо шашлык курица говядина стейк картофель утка селёдка свинина котлета тунец бифштекс
#
# Группа 3: Закуски
# сыр салат овощ баклажан гриб лук помидор чеснок лимон сало печень лосось сёмигор креветка мидия устрица краб
#
# Группа 4: Выпечка
# хлеб круассан блинчик булочка пирожное торт пирог драник пончик
#
# Группа 5: Десерты
# мороженое пирог пирожное чизкейк медовик шоколад бутерброд вафля манго спагетти макароны клубника маршмеллоу маршмеллоу маффин
#
# Группа 6: Блюда из рыбы и морепродуктов
# рыба сёмигор креветка мидия устрица краб лосось сёмигор стеганин горошек шпрот
#
# Группа 7: Бургеры и фастфуд
# бургер шаурма пончик фри фастфуд чипс гамбургер чизбургер
#
# Группа 8: Итальянская кухня
# пицца паста ролл блин пельмени лагман солянка карпаччо струдель рис плов кальмар тортилья пудинг
#
# Группа 9: Грузинская кухня
# хачапури хинкали чахохбили
#
# ...

# %% [markdown]
# кофе
# пицца
# пиво
# салат
# мясо
# шашлык
# суп
# чай
# рыба
# бургер
# ролл
# коктейль
# курица
# шаверма
# вино
# говядина
# овощ
# сыр
# паста
# хлеб
# морепродукт
# картошка
# стейк
# мороженое
# креветка
# борщ
# круассан
# гриль
# блин
# пельмень
# лапша
# фри
# баклажан
# рис
# плов
# кальмар
# торт
# картофель
# лимонад
# хачапури
# гриб
# булочка
# алкоголь
# котлета
# тунец
# вафля
# масло
# колбаска
# капуста
# пюре
# чебурек
# лосось
# яйцо
# свинина
# сырник
# лагман
# солянка
# каша
# чизкейк
# ребро
# утка
# хинкали
# устрица
# кебаб
# пирожное
# морс
# блинчик
# драник
# лук
# помидор
# мидия
# фастфуд
# омлет
# лимон
# сало
# сосиска
# пирог
# филе
# вишня
# вареник
# тартар
# угорь
# селёдка
# печень
# паштет
# шоколад
# какао
# ягода
# гамбургер
# телятина
# краб
# бифштекс
# чеснок
# уха
# медовик
# оливье
# гребешок
# бутерброд
# груша
# тост
# манго
# спагетти
# штрудель
# ризотто
# макароны
# клубника
# сэндвич
# ростбиф
# сельдь
# форель
# ананас
# банан
# хотдог
# водка
# малина
# чипс
# брускетта
# мандарин
# рулет
# апельсин
# творог
# колбаса
# томат
# карри
# корица
# яблоко
# карамель
# яичница
# трюфель
# оливка
# шампанское
# гречка
# конфета
# карпаччо
# жаркое
# окрошка
# чипсы
# йогурт
# виски
# кукуруза
# тортилья
# пончик
# клюква
# кокос
# кекс
# барашек
# чизбургер
# квас
# желе
# фрикаделька
# гуляш
# голубец
# пломбир
# рибай
# виноград
# моцарелла
# щи
# тарталетка
# пахлава
# аперитив
# кабачок
# бефстроганов
# мусс
# попкорн
# арбуз
# маршмеллоу
# беляш
# грейпфрут
# шницель
# кефир
# лимончелло
# лагер
# винегрет
# милкшейк
# крендель
# персик
# тарт
# изюм
# маффин
# улитка
# киви
# рагу
# вафелька
# медовуха
# горошек
# шпрот
# рататуй
# джем
# сом
# мартини
# фондю
# кисель
# карбонат
# масленица
# дыня
# гаспаччо
# манты
# чахохбили
# пудинг
# тапас
# стурганин
